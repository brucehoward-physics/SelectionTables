# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import SelTable as tbl

# %%
# Change example.csv to the 
with open('example.csv') as _file:
    df = pd.read_csv(_file)

# %%
df
# Out:
#    Sample   No Cut  Cut A  Cut B  Full Selection
# 0   NueCC    100.0   80.0   70.0            60.0
# 1  NumuCC   1000.0  400.0   20.0            10.0
# 2      NC    800.0   30.0  100.0             5.0
# 3  Cosmic  10000.0  100.0  300.0            80.0

# %%
df.columns
# Out:
# Index(['Sample', 'No Cut', 'Cut A', 'Cut B', 'Full Selection'], dtype='object')

# %%
# BELOW HERE IS WHERE YOU MAKE THE TABLE YOU WANT BY GIVING IT A SET OF CUTS AND SET OPTIONS

# This is the function that is being used:
#   def makeSelectionPlot(inDF,cuts=[],signalLabel='NueCC',norm=False,grid=False):

# Note - this assumes you are using the standard precision of output of 6 digits, so values > 100000
#        have the decimal point removed in the table

# %%
tbl.makeSelectionPlot(df,cuts=['No Cut','Cut A','Cut B','Full Selection'])

# %%
tbl.makeSelectionPlot(df,cuts=['No Cut','Cut A','Cut B','Full Selection'],norm=True)

# %%
tbl.makeSelectionPlot(df,cuts=['No Cut','Cut A','Cut B','Full Selection'],signalLabel='NumuCC')
